# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# %%
train_dir = r"C:\Users\Sharooz Ali\Desktop\Local Disk(D)\Python_MachineLearning\asl_dataset\asl_train"

# %%
IMG_SIZE = 96  
BATCH_SIZE = 32

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.15,

    rotation_range=15,
    zoom_range=0.15,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.1,

    brightness_range=[0.8, 1.2],
    fill_mode='nearest'
)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)
# Out:
# Found 1556 images belonging to 26 classes.

# %%
val_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 259 images belonging to 26 classes.

# %%
num_classes = train_generator.num_classes

# %%
model = Sequential()

# Block 1
model.add(Conv2D(32, (3,3), activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))

# Block 2
model.add(Conv2D(64, (3,3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))

# Block 3
model.add(Conv2D(128, (3,3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))

# Block 4
model.add(Conv2D(256, (3,3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(2,2))


model.add(tf.keras.layers.GlobalAveragePooling2D())

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(num_classes, activation='softmax'))
# Out:
# C:\Users\Sharooz Ali\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 94, 94, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 94, 94, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 47, 47, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 45, 45, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 45, 45, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 20, 20, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 20, 20, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 10, 10, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 8, 8, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 8, 8, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 4, 4, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 256)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │          65,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 26)                  │           6,682 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 462,810 (1.77 MB)
#  Trainable params: 461,850 (1.76 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
early_stop = EarlyStopping(
    monitor='val_accuracy',
    patience=10,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-6
)

checkpoint = ModelCheckpoint(
    "asl_best_model.keras",
    monitor="val_accuracy",
    save_best_only=True,
    verbose=1
)

# %%
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=20,
    callbacks=[early_stop, reduce_lr, checkpoint]
)
# Out:
# Epoch 1/20
# C:\Users\Sharooz Ali\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 723ms/step - accuracy: 0.1400 - loss: 3.0339
# Epoch 1: val_accuracy improved from -inf to 0.05019, saving model to asl_best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 66s 871ms/step - accuracy: 0.1413 - loss: 3.0273 - val_accuracy: 0.0502 - val_loss: 3.3048 - learning_rate: 5.0000e-04
# Epoch 2/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 657ms/step - accuracy: 0.3971 - loss: 1.9509
# Epoch 2: val_accuracy improved from 0.05019 to 0.06564, saving model to asl_best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 760ms/step - accuracy: 0.3978 - loss: 1.9478 - val_accuracy: 0.0656 - val_loss: 3.4394 - learning_rate: 5.0000e-04
# Epoch 3/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 650ms/step - accuracy: 0.5708 - loss: 1.3743
# Epoch 3: val_accuracy did not improve from 0.06564
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 40s 747ms/step - accuracy: 0.5715 - loss: 1.3715 - val_accuracy: 0.0579 - val_loss: 3.4817 - learning_rate: 5.0000e-04
# Epoch 4/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 686ms/step - accuracy: 0.7118 - loss: 0.9315
# Epoch 4: val_accuracy did not improve from 0.06564
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 781ms/step - accuracy: 0.7125 - loss: 0.9299 - val_accuracy: 0.0618 - val_loss: 3.3284 - learning_rate: 5.0000e-04
# Epoch 5/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 712ms/step - accuracy: 0.8116 - loss: 0.6267
# Epoch 5: val_accuracy improved from 0.06564 to 0.08108, saving model to asl_best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 45s 805ms/step - accuracy: 0.8118 - loss: 0.6262 - val_accuracy: 0.0811 - val_loss: 3.2894 - learning_rate: 2.5000e-04
# Epoch 6/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 641ms/step - accuracy: 0.8587 - loss: 0.5157
# Epoch 6: val_accuracy improved from 0.08108 to 0.11197, saving model to asl_best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 40s 744ms/step - accuracy: 0.8588 - loss: 0.5149 - val_accuracy: 0.1120 - val_loss: 2.9992 - learning_rate: 2.5000e-04
# Epoch 7/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 671ms/step - accuracy: 0.8922 - loss: 0.4037
# Epoch 7: val_accuracy improved from 0.11197 to 0.18147, saving model to asl_best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 777ms/step - accuracy: 0.8922 - loss: 0.4035 - val_accuracy: 0.1815 - val_loss: 2.8065 - learning_rate: 2.5000e-04
# Epoch 8/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 648ms/step - accuracy: 0.8967 - loss: 0.3494
# Epoch 8: val_accuracy improved from 0.18147 to 0.31274, saving model to asl_best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 40s 739ms/step - accuracy: 0.8969 - loss: 0.3493 - val_accuracy: 0.3127 - val_loss: 2.3655 - learning_rate: 2.5000e-04
# Epoch 9/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 695ms/step - accuracy: 0.9168 - loss: 0.3044
# Epoch 9: val_accuracy improved from 0.31274 to 0.50579, saving model to asl_best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 791ms/step - accuracy: 0.9169 - loss: 0.3042 - val_accuracy: 0.5058 - val_loss: 1.8312 - learning_rate: 2.5000e-04
# Epoch 10/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 653ms/step - accuracy: 0.9340 - loss: 0.2582
# Epoch 10: val_accuracy improved from 0.50579 to 0.69884, saving model to asl_best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 759ms/step - accuracy: 0.9338 - loss: 0.2586 - val_accuracy: 0.6988 - val_loss: 1.3276 - learning_rate: 2.5000e-04
# Epoch 11/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 667ms/step - accuracy: 0.9436 - loss: 0.2459
# Epoch 11: val_accuracy did not improve from 0.69884
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 751ms/step - accuracy: 0.9438 - loss: 0.2456 - val_accuracy: 0.6873 - val_loss: 1.1925 - learning_rate: 2.5000e-04
# Epoch 12/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 678ms/step - accuracy: 0.9564 - loss: 0.2050
# Epoch 12: val_accuracy improved from 0.69884 to 0.88031, saving model to asl_best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 777ms/step - accuracy: 0.9564 - loss: 0.2051 - val_accuracy: 0.8803 - val_loss: 0.4970 - learning_rate: 2.5000e-04
# Epoch 13/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 672ms/step - accuracy: 0.9557 - loss: 0.1807
# Epoch 13: val_accuracy improved from 0.88031 to 0.94981, saving model to asl_best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 781ms/step - accuracy: 0.9556 - loss: 0.1807 - val_accuracy: 0.9498 - val_loss: 0.3138 - learning_rate: 2.5000e-04
# Epoch 14/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 660ms/step - accuracy: 0.9581 - loss: 0.1555
# Epoch 14: val_accuracy improved from 0.94981 to 0.95753, saving model to asl_best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 40s 763ms/step - accuracy: 0.9583 - loss: 0.1554 - val_accuracy: 0.9575 - val_loss: 0.2899 - learning_rate: 2.5000e-04
# Epoch 15/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 705ms/step - accuracy: 0.9693 - loss: 0.1271
# Epoch 15: val_accuracy did not improve from 0.95753
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 43s 805ms/step - accuracy: 0.9692 - loss: 0.1273 - val_accuracy: 0.9073 - val_loss: 0.3750 - learning_rate: 2.5000e-04
# Epoch 16/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 653ms/step - accuracy: 0.9734 - loss: 0.1315
# Epoch 16: val_accuracy did not improve from 0.95753
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 40s 744ms/step - accuracy: 0.9733 - loss: 0.1315 - val_accuracy: 0.8185 - val_loss: 0.5527 - learning_rate: 2.5000e-04
# Epoch 17/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 685ms/step - accuracy: 0.9762 - loss: 0.1229
# Epoch 17: val_accuracy improved from 0.95753 to 0.96525, saving model to asl_best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 783ms/step - accuracy: 0.9762 - loss: 0.1230 - val_accuracy: 0.9653 - val_loss: 0.1964 - learning_rate: 2.5000e-04
# Epoch 18/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 683ms/step - accuracy: 0.9797 - loss: 0.1013
# Epoch 18: val_accuracy did not improve from 0.96525
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 776ms/step - accuracy: 0.9796 - loss: 0.1013 - val_accuracy: 0.9344 - val_loss: 0.2373 - learning_rate: 2.5000e-04
# Epoch 19/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 876ms/step - accuracy: 0.9707 - loss: 0.1059
# Epoch 19: val_accuracy improved from 0.96525 to 0.97683, saving model to asl_best_model.keras
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 51s 981ms/step - accuracy: 0.9708 - loss: 0.1059 - val_accuracy: 0.9768 - val_loss: 0.1639 - learning_rate: 2.5000e-04
# Epoch 20/20
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 0s 676ms/step - accuracy: 0.9900 - loss: 0.0777
# Epoch 20: val_accuracy did not improve from 0.97683
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 771ms/step - accuracy: 0.9899 - loss: 0.0778 - val_accuracy: 0.9459 - val_loss: 0.1838 - learning_rate: 2.5000e-04

# %%
model.save("asl_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
model.save("asl_model.keras")
print("Model saved successfully")
# Out:
# Model saved successfully
